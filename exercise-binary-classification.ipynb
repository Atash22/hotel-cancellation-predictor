# %% [markdown]
# # Introduction #
#
# This model will predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('hotel_bookings.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %%
from tensorflow import keras
from tensorflow.keras import layers

# define the model given in the diagram
model = keras.Sequential([
    # Input block
    layers.BatchNormalization(input_shape=input_shape),
    
    # Block 1
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    
    # Block 2
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    
    # Output
    layers.Dense(1, activation='sigmoid'),
])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from tensorflow import keras
#       2 from tensorflow.keras import layers
#       4 # define the model given in the diagram
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)
# Out:
# Correct

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779141119.463174     522 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 175/175 [==============================] - 6s 7ms/step - loss: 0.4758 - binary_accuracy: 0.7746 - val_loss: 0.4366 - val_binary_accuracy: 0.8021
# Epoch 2/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.4220 - binary_accuracy: 0.8023 - val_loss: 0.4055 - val_binary_accuracy: 0.8123
# Epoch 3/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.4093 - binary_accuracy: 0.8082 - val_loss: 0.3962 - val_binary_accuracy: 0.8154
# Epoch 4/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.4028 - binary_accuracy: 0.8122 - val_loss: 0.3936 - val_binary_accuracy: 0.8172
# Epoch 5/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3980 - binary_accuracy: 0.8149 - val_loss: 0.3875 - val_binary_accuracy: 0.8183
# Epoch 6/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3925 - binary_accuracy: 0.8175 - val_loss: 0.3856 - val_binary_accuracy: 0.8210
# Epoch 7/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3901 - binary_accuracy: 0.8191 - val_loss: 0.3811 - val_binary_accuracy: 0.8205
# Epoch 8/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3855 - binary_accuracy: 0.8221 - val_loss: 0.3834 - val_binary_accuracy: 0.8227
# Epoch 9/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3828 - binary_accuracy: 0.8229 - val_loss: 0.3792 - val_binary_accuracy: 0.8254
# Epoch 10/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3814 - binary_accuracy: 0.8227 - val_loss: 0.3741 - val_binary_accuracy: 0.8270
# Epoch 11/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3774 - binary_accuracy: 0.8272 - val_loss: 0.3745 - val_binary_accuracy: 0.8283
# Epoch 12/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3740 - binary_accuracy: 0.8289 - val_loss: 0.3695 - val_binary_accuracy: 0.8290
# Epoch 13/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3729 - binary_accuracy: 0.8282 - val_loss: 0.3693 - val_binary_accuracy: 0.8299
# Epoch 14/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3699 - binary_accuracy: 0.8307 - val_loss: 0.3672 - val_binary_accuracy: 0.8297
# Epoch 15/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3665 - binary_accuracy: 0.8322 - val_loss: 0.3722 - val_binary_accuracy: 0.8272
# Epoch 16/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3661 - binary_accuracy: 0.8314 - val_loss: 0.3649 - val_binary_accuracy: 0.8326
# Epoch 17/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3639 - binary_accuracy: 0.8321 - val_loss: 0.3606 - val_binary_accuracy: 0.8312
# Epoch 18/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3616 - binary_accuracy: 0.8336 - val_loss: 0.3613 - val_binary_accuracy: 0.8336
# Epoch 19/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3618 - binary_accuracy: 0.8341 - val_loss: 0.3615 - val_binary_accuracy: 0.8334
# Epoch 20/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3583 - binary_accuracy: 0.8361 - val_loss: 0.3595 - val_binary_accuracy: 0.8343
# Epoch 21/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3569 - binary_accuracy: 0.8359 - val_loss: 0.3581 - val_binary_accuracy: 0.8331
# Epoch 22/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3550 - binary_accuracy: 0.8370 - val_loss: 0.3588 - val_binary_accuracy: 0.8330
# Epoch 23/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3542 - binary_accuracy: 0.8373 - val_loss: 0.3586 - val_binary_accuracy: 0.8326
# Epoch 24/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3531 - binary_accuracy: 0.8377 - val_loss: 0.3578 - val_binary_accuracy: 0.8357
# Epoch 25/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3519 - binary_accuracy: 0.8385 - val_loss: 0.3541 - val_binary_accuracy: 0.8354
# Epoch 26/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3529 - binary_accuracy: 0.8374 - val_loss: 0.3558 - val_binary_accuracy: 0.8360
# Epoch 27/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3490 - binary_accuracy: 0.8398 - val_loss: 0.3541 - val_binary_accuracy: 0.8360
# Epoch 28/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3486 - binary_accuracy: 0.8402 - val_loss: 0.3551 - val_binary_accuracy: 0.8349
# Epoch 29/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3468 - binary_accuracy: 0.8411 - val_loss: 0.3556 - val_binary_accuracy: 0.8355
# Epoch 30/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3483 - binary_accuracy: 0.8400 - val_loss: 0.3557 - val_binary_accuracy: 0.8358
# <Axes: title={'center': 'Accuracy'}>

# %%
import joblib

# Save model and preprocessor
joblib.dump(model, 'model.pkl')
joblib.dump(preprocessor, 'preprocessor.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import joblib
#       3 # Save model and preprocessor
# ----> 4 joblib.dump(model, 'model.pkl')
#       5 joblib.dump(preprocessor, 'preprocessor.pkl')
#
# NameError: name 'model' is not defined
